# %%
import random
import numpy as np
from IPython.display import display, clear_output

# %%
class Jogo8Puzzle:
    def __init__(self):
        self.estado_objetivo = np.array([
                                [1, 2, 3],
                                [4, 5, 6],
                                [7, 8, 0]
                            ])
        
        self.estado_atual = self.estado_objetivo.copy()
        self.embaralhar()

    def embaralhar(self):
        for _ in range(3):
            self.mover_aleatorio()

    def mover_aleatorio(self):
        movimentos_possiveis = self.obter_movimentos_possiveis()
        if movimentos_possiveis:
            # movimento = [ tupla(linha, coluna), direcao ]
            # movimento[0] = tupla(linha, coluna)
            movimento = random.choice(movimentos_possiveis)
            self.mover(movimento[0])

    def obter_movimentos_possiveis(self):
        linha_vazia, coluna_vazia = np.where(self.estado_atual == 0)
        # np.where -> tupla (linha, coluna)
        movimentos_possiveis = []
        # tupla(linha, coluna), direcao

        # w -> cima, s -> baixo, a -> esquerda, d -> direita
        # [2],[2]
        if linha_vazia > 0:
            movimentos_possiveis.append((
                (linha_vazia - 1, coluna_vazia), 'w'
            ))

        if linha_vazia < 2:
            movimentos_possiveis.append((
                (linha_vazia + 1, coluna_vazia), 's'
            ))

        if coluna_vazia > 0:
            movimentos_possiveis.append((
                (linha_vazia, coluna_vazia - 1), 'a'
            ))
        
        if coluna_vazia < 2:
            movimentos_possiveis.append((
                (linha_vazia, coluna_vazia + 1), 'd'
            ))

        return movimentos_possiveis  

    def mover(self, posicao):
        linha_vazia, coluna_vazia = np.where(self.estado_atual == 0)
        nova_linha, nova_coluna = posicao

        self.estado_atual[linha_vazia, coluna_vazia], self.estado_atual[nova_linha, nova_coluna] = \
            self.estado_atual[nova_linha, nova_coluna], self.estado_atual[linha_vazia, coluna_vazia]
    
    def mostrar_tabuleiro(self):
        print(self.estado_atual)

    def jogar(self):
        jogo_ativo = True
        while jogo_ativo:
            clear_output(wait=True)
            self.mostrar_tabuleiro()
            print("Use as teclas w, s, a, d para mover o espaço vazio")

            movimentos_possiveis = self.obter_movimentos_possiveis()
            print("Movimentos possíveis:")
            for movimento in movimentos_possiveis:
                posicao, direcao = movimento
                linha, coluna = posicao
                peca = self.estado_atual[linha, coluna]
                print(f"{direcao}: Mover peça {peca}. Posição {linha}, {coluna}")
            movimento = input("Digite o movimento: ").lower()

            if movimento == 'q':
                jogo_ativo = False
                print("Jogo encerrado")
                break
            elif movimento in ['w', 'a', 's', 'd']:
                # Filtra movimentos válidos
                movimentos_validos = []
                # Se o movimento for igual ao movimento informado, adiciona na lista
                for mov in movimentos_possiveis:
                    direcao = mov[1]
                    movimentos_validos.append(direcao)

                if movimento in movimentos_validos:
                    for movimento_possivel in movimentos_possiveis:
                        if movimento_possivel[1] == movimento:
                            posicao = movimento_possivel[0]
                            self.mover(posicao)
                            break
            else:
                print("Movimento inválido")

            if np.array_equal(self.estado_atual, self.estado_objetivo):
                clear_output(wait=True)
                self.mostrar_tabuleiro()
                print("Parabéns, você venceu!")
                jogo_ativo = False

# %%
jogo = Jogo8Puzzle()
jogo.jogar()
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# Use as teclas w, s, a, d para mover o espaço vazio
# Movimentos possíveis:
# w: Mover peça [5]. Posição [1], [1]
# a: Mover peça [7]. Posição [2], [0]
# d: Mover peça [8]. Posição [2], [2]
# Jogo encerrado

# %% [markdown]
# Atividade Aula 02 - Algoritmo BFS

# %%
import numpy as np

def estado_para_string(estado):
    return ''.join(str(i) for i in estado.flatten())

def busca_em_largura(estado_inicial):
    fila = []
    fila.append([estado_inicial.estado_atual, []])
    tamanho_busca = 0

    visitados = set()
    visitados.add(estado_para_string(estado_inicial.estado_atual))
    while fila:
        estado, caminho = fila.pop(0)

        jogo_while = Jogo8Puzzle()
        jogo_while.estado_atual = np.array(estado)

        if np.array_equal(jogo_while.estado_atual, jogo_while.estado_objetivo):
            return (caminho, tamanho_busca)
        else:
            tamanho_busca += 1
        
        movimentos_possiveis = jogo_while.obter_movimentos_possiveis()

        if movimentos_possiveis:
            for posicao, direcao in movimentos_possiveis:             

                jogo_for = Jogo8Puzzle()
                jogo_for.estado_atual = jogo_while.estado_atual.copy()
                jogo_for.mover(posicao)                              

                if estado_para_string(jogo_for.estado_atual) in visitados:
                    continue
                else:
                    atualiza_caminho = caminho[:]
                    atualiza_caminho.append(direcao)
                    #print(posicao, direcao, "\n", jogo_for.estado_atual)

                    visitados.add(estado_para_string(jogo_for.estado_atual))
                    fila.append([jogo_for.estado_atual, atualiza_caminho])
    
    return None

# Crie uma instância da classe Jogo8Puzzle com o estado inicial desejado
jogo = Jogo8Puzzle()
'''
jogo.estado_atual = np.array([[4, 1, 3],
                              [7, 6, 0],
                              [5, 2, 8]])

'''
jogo.estado_atual = np.array([[1, 2, 3],
                              [4, 5, 6],
                              [7, 0, 8]])


# Execute o algoritmo BFS para encontrar a sequência de jogadas que resolvem o problema
sequencia_jogadas, tamanho_busca = busca_em_largura(jogo)

# Exiba a sequência de jogadas
if sequencia_jogadas:
    print("Sequência de jogadas para resolver o problema:")
    print(jogo.estado_atual)
    
    for direcao in sequencia_jogadas:
        print(f"Mover para a direção {direcao}")
        
    print(sequencia_jogadas)
    print(f"Jogo resolvido em {len(sequencia_jogadas)} jogada(s), com busca em {tamanho_busca} estados.")
else:
    print("Não foi possível encontrar uma solução.")
# Out:
# Sequência de jogadas para resolver o problema:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# Mover para a direção d
# ['d']
# Jogo resolvido em 1 jogada(s), com busca em 3 estados.

# %% [markdown]
# Algoritmo de Busca em Profundidade

# %%
import numpy as np

def estado_para_string(estado):
    return ''.join(str(i) for i in estado.flatten())

def busca_em_profundidade(estado_atual, caminho_atual, visitados, max_profundidade):
    if estado_para_string(estado_atual) in visitados:
        return None

    visitados.add(estado_para_string(estado_atual))

    if np.array_equal(estado_atual, jogo.estado_objetivo):
        return caminho_atual

    if max_profundidade == 0:
        return None

    movimentos_possiveis = obter_movimentos_possiveis(estado_atual)

    for posicao, direcao in movimentos_possiveis:
        novo_estado = estado_atual.copy()
        mover(novo_estado, posicao)

        novo_caminho = caminho_atual[:]
        novo_caminho.append(direcao)

        resultado = busca_em_profundidade(novo_estado, novo_caminho, visitados, max_profundidade - 1)
        if resultado is not None:
            return resultado
    
    return None

def obter_movimentos_possiveis(estado):
    linha_vazia, coluna_vazia = np.where(estado == 0)
    movimentos_possiveis = []

    if linha_vazia > 0:
        movimentos_possiveis.append(((linha_vazia - 1, coluna_vazia), 'w'))

    if linha_vazia < 2:
        movimentos_possiveis.append(((linha_vazia + 1, coluna_vazia), 's'))

    if coluna_vazia > 0:
        movimentos_possiveis.append(((linha_vazia, coluna_vazia - 1), 'a'))
    
    if coluna_vazia < 2:
        movimentos_possiveis.append(((linha_vazia, coluna_vazia + 1), 'd'))

    return movimentos_possiveis

def mover(estado, posicao):
    linha_vazia, coluna_vazia = np.where(estado == 0)
    nova_linha, nova_coluna = posicao
    estado[linha_vazia, coluna_vazia], estado[nova_linha, nova_coluna] = estado[nova_linha, nova_coluna], estado[linha_vazia, coluna_vazia]


# Criação do jogo
jogo = Jogo8Puzzle()

# Definir estado inicial desejado aqui
estado_inicial_desejado = np.array([
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
])

# Chamar a busca em profundidade
sequencia_jogadas = busca_em_profundidade(jogo.estado_atual, [], set(), max_profundidade=100)

if sequencia_jogadas:
    print("Sequência de jogadas para resolver o problema:")
    print(jogo.estado_atual)
    
    for direcao in sequencia_jogadas:
        print(f"Mover para a direção {direcao}")
        
    print(sequencia_jogadas)
    print(f"Jogo resolvido em {len(sequencia_jogadas)} jogada(s).")
else:
    print("Solução não encontrada dentro da profundidade máxima.")
# Out:
# Sequência de jogadas para resolver o problema:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção a
# Mover para a direção w
# Mover para a direção d
# Mover para a direção w
# Mover para a direção a
# Mover para a direção s
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção a
# Mover para a direção w
# Mover para a direção d
# Mover para a direção s
# Mover para a direção a
# Mover para a direção s
# Mover para a direção d
# Mover para a direção w
# Mover para a direção w
# Mover para a direção d
# Mover para a direção s
# Mover para a direção s
# ['w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 'd', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'w', 'w', 'a', 's', 's', 'd', 'd', 'w', 'w', 'a', 's', 's', 'a', 'w', 'd', 'w', 'a', 's', 's', 'd', 'w', 'a', 'w', 'd', 's', 'a', 's', 'd', 'w', 'w', 'd', 's', 's']
# Jogo resolvido em 85 jogada(s).

# %% [markdown]
# Algoritmo do Professor para a busca por profundidade (DFS)

# %%
def busca_em_profundidade(estado_inicial, limite_profundidade):
    pilha = []  # pilha de estados

    pilha.append([
        estado_inicial.estado_atual,  # estado
        []  # caminho
    ])  # inserindo o estado inicial(root) na pilha
    tamanho_busca = 0

    visitados = set()  # conjunto de estados visitados
    visitados.add(estado_para_string(estado_inicial.estado_atual))

    while pilha:
        # LIFO
        estado, caminho = pilha.pop()  # remove o último elemento da pilha

        jogo_pilha = Jogo8Puzzle()
        jogo_pilha.estado_atual = np.array(estado)

        print(f"Profundidade: {tamanho_busca} Estado:\n {jogo_pilha.estado_atual}")

        if np.array_equal(jogo_pilha.estado_atual, jogo_pilha.estado_objetivo):
            return (caminho, tamanho_busca)  # tupla
        else:
            tamanho_busca += 1

        if tamanho_busca > limite_profundidade:
            continue  # Evitar explorar além do limite de profundidade

        movimentos_possiveis = jogo_pilha.obter_movimentos_possiveis()

        if movimentos_possiveis:
            for posicao, direcao in movimentos_possiveis:
                jogo_pilha = Jogo8Puzzle()
                jogo_pilha.estado_atual = np.array(estado)
                jogo_pilha.mover(posicao)

                if estado_para_string(jogo_pilha.estado_atual) in visitados:
                    continue
                else:
                    atualiza_caminho = caminho[:]
                    atualiza_caminho.append(direcao)

                    visitados.add(estado_para_string(jogo_pilha.estado_atual))
                    pilha.append([jogo_pilha.estado_atual, atualiza_caminho])

    return (None, tamanho_busca)

# %%
# Crie uma instância da classe Jogo8Puzzle com o estado inicial desejado
jogo = Jogo8Puzzle() # objeto do jogo, instância da classe Jogo8Puzzle
'''
jogo.estado_atual = np.array([[4, 6, 1],
                              [7, 2, 3],
                              [5, 0, 8]])

'''
jogo.estado_atual = np.array([[1, 0, 3],
                              [4, 2, 5],
                              [7, 8, 6]])


# Execute o algoritmo BFS para encontrar a sequência de jogadas que resolvem o problema
sequencia_jogadas, tamanho_busca = busca_em_profundidade(jogo, 100)

# Exiba a sequência de jogadas
if sequencia_jogadas:
    print("Sequência de jogadas para resolver o problema:")
    print(jogo.estado_atual)
    
    for direcao in sequencia_jogadas:
        print(f"Mover para a direção {direcao}")
        
    print(sequencia_jogadas)
    print(f"Jogo resolvido em {len(sequencia_jogadas)} jogada(s), com busca em {tamanho_busca} estados.")
else:
    print("Não foi possível encontrar uma solução.")
# Out:
# Profundidade: 0 Estado:
#  [[1 0 3]
#  [4 2 5]
#  [7 8 6]]
# Profundidade: 1 Estado:
#  [[1 3 0]
#  [4 2 5]
#  [7 8 6]]
# Profundidade: 2 Estado:
#  [[1 3 5]
#  [4 2 0]
#  [7 8 6]]
# Profundidade: 3 Estado:
#  [[1 3 5]
#  [4 0 2]
#  [7 8 6]]
# Profundidade: 4 Estado:
#  [[1 3 5]
#  [0 4 2]
#  [7 8 6]]
# Profundidade: 5 Estado:
#  [[1 3 5]
#  [7 4 2]
#  [0 8 6]]
# Profundidade: 6 Estado:
#  [[1 3 5]
#  [7 4 2]
#  [8 0 6]]
# Profundidade: 7 Estado:
#  [[1 3 5]
#  [7 4 2]
#  [8 6 0]]
# Profundidade: 8 Estado:
#  [[1 3 5]
#  [7 4 0]
#  [8 6 2]]
# Profundidade: 9 Estado:
#  [[1 3 5]
#  [7 0 4]
#  [8 6 2]]
# Profundidade: 10 Estado:
#  [[1 3 5]
#  [0 7 4]
#  [8 6 2]]
# Profundidade: 11 Estado:
#  [[1 3 5]
#  [8 7 4]
#  [0 6 2]]
# Profundidade: 12 Estado:
#  [[1 3 5]
#  [8 7 4]
#  [6 0 2]]
# Profundidade: 13 Estado:
#  [[1 3 5]
#  [8 7 4]
#  [6 2 0]]
# Profundidade: 14 Estado:
#  [[1 3 5]
#  [8 7 0]
#  [6 2 4]]
# Profundidade: 15 Estado:
#  [[1 3 5]
#  [8 0 7]
#  [6 2 4]]
# Profundidade: 16 Estado:
#  [[1 3 5]
#  [0 8 7]
#  [6 2 4]]
# Profundidade: 17 Estado:
#  [[1 3 5]
#  [6 8 7]
#  [0 2 4]]
# Profundidade: 18 Estado:
#  [[1 3 5]
#  [6 8 7]
#  [2 0 4]]
# Profundidade: 19 Estado:
#  [[1 3 5]
#  [6 8 7]
#  [2 4 0]]
# Profundidade: 20 Estado:
#  [[1 3 5]
#  [6 8 0]
#  [2 4 7]]
# Profundidade: 21 Estado:
#  [[1 3 5]
#  [6 0 8]
#  [2 4 7]]
# Profundidade: 22 Estado:
#  [[1 3 5]
#  [0 6 8]
#  [2 4 7]]
# Profundidade: 23 Estado:
#  [[1 3 5]
#  [2 6 8]
#  [0 4 7]]
# Profundidade: 24 Estado:
#  [[1 3 5]
#  [2 6 8]
#  [4 0 7]]
# Profundidade: 25 Estado:
#  [[1 3 5]
#  [2 6 8]
#  [4 7 0]]
# Profundidade: 26 Estado:
#  [[1 3 5]
#  [2 6 0]
#  [4 7 8]]
# Profundidade: 27 Estado:
#  [[1 3 5]
#  [2 0 6]
#  [4 7 8]]
# Profundidade: 28 Estado:
#  [[1 3 5]
#  [0 2 6]
#  [4 7 8]]
# Profundidade: 29 Estado:
#  [[1 3 5]
#  [4 2 6]
#  [0 7 8]]
# Profundidade: 30 Estado:
#  [[1 3 5]
#  [4 2 6]
#  [7 0 8]]
# Profundidade: 31 Estado:
#  [[1 3 5]
#  [4 0 6]
#  [7 2 8]]
# Profundidade: 32 Estado:
#  [[1 3 5]
#  [4 6 0]
#  [7 2 8]]
# Profundidade: 33 Estado:
#  [[1 3 5]
#  [4 6 8]
#  [7 2 0]]
# Profundidade: 34 Estado:
#  [[1 3 5]
#  [4 6 8]
#  [7 0 2]]
# Profundidade: 35 Estado:
#  [[1 3 5]
#  [4 6 8]
#  [0 7 2]]
# Profundidade: 36 Estado:
#  [[1 3 5]
#  [0 6 8]
#  [4 7 2]]
# Profundidade: 37 Estado:
#  [[1 3 5]
#  [6 0 8]
#  [4 7 2]]
# Profundidade: 38 Estado:
#  [[1 3 5]
#  [6 8 0]
#  [4 7 2]]
# Profundidade: 39 Estado:
#  [[1 3 5]
#  [6 8 2]
#  [4 7 0]]
# Profundidade: 40 Estado:
#  [[1 3 5]
#  [6 8 2]
#  [4 0 7]]
# Profundidade: 41 Estado:
#  [[1 3 5]
#  [6 8 2]
#  [0 4 7]]
# Profundidade: 42 Estado:
#  [[1 3 5]
#  [0 8 2]
#  [6 4 7]]
# Profundidade: 43 Estado:
#  [[1 3 5]
#  [8 0 2]
#  [6 4 7]]
# Profundidade: 44 Estado:
#  [[1 3 5]
#  [8 2 0]
#  [6 4 7]]
# Profundidade: 45 Estado:
#  [[1 3 5]
#  [8 2 7]
#  [6 4 0]]
# Profundidade: 46 Estado:
#  [[1 3 0]
#  [8 2 5]
#  [6 4 7]]
# Profundidade: 47 Estado:
#  [[1 0 3]
#  [8 2 5]
#  [6 4 7]]
# Profundidade: 48 Estado:
#  [[0 1 3]
#  [8 2 5]
#  [6 4 7]]
# Profundidade: 49 Estado:
#  [[8 1 3]
#  [0 2 5]
#  [6 4 7]]
# Profundidade: 50 Estado:
#  [[8 1 3]
#  [2 0 5]
#  [6 4 7]]
# Profundidade: 51 Estado:
#  [[8 1 3]
#  [2 5 0]
#  [6 4 7]]
# Profundidade: 52 Estado:
#  [[8 1 3]
#  [2 5 7]
#  [6 4 0]]
# Profundidade: 53 Estado:
#  [[8 1 3]
#  [2 5 7]
#  [6 0 4]]
# Profundidade: 54 Estado:
#  [[8 1 3]
#  [2 5 7]
#  [0 6 4]]
# Profundidade: 55 Estado:
#  [[8 1 3]
#  [0 5 7]
#  [2 6 4]]
# Profundidade: 56 Estado:
#  [[8 1 3]
#  [5 0 7]
#  [2 6 4]]
# Profundidade: 57 Estado:
#  [[8 1 3]
#  [5 7 0]
#  [2 6 4]]
# Profundidade: 58 Estado:
#  [[8 1 3]
#  [5 7 4]
#  [2 6 0]]
# Profundidade: 59 Estado:
#  [[8 1 3]
#  [5 7 4]
#  [2 0 6]]
# Profundidade: 60 Estado:
#  [[8 1 3]
#  [5 7 4]
#  [0 2 6]]
# Profundidade: 61 Estado:
#  [[8 1 3]
#  [0 7 4]
#  [5 2 6]]
# Profundidade: 62 Estado:
#  [[8 1 3]
#  [7 0 4]
#  [5 2 6]]
# Profundidade: 63 Estado:
#  [[8 1 3]
#  [7 4 0]
#  [5 2 6]]
# Profundidade: 64 Estado:
#  [[8 1 3]
#  [7 4 6]
#  [5 2 0]]
# Profundidade: 65 Estado:
#  [[8 1 3]
#  [7 4 6]
#  [5 0 2]]
# Profundidade: 66 Estado:
#  [[8 1 3]
#  [7 4 6]
#  [0 5 2]]
# Profundidade: 67 Estado:
#  [[8 1 3]
#  [0 4 6]
#  [7 5 2]]
# Profundidade: 68 Estado:
#  [[8 1 3]
#  [4 0 6]
#  [7 5 2]]
# Profundidade: 69 Estado:
#  [[8 1 3]
#  [4 6 0]
#  [7 5 2]]
# Profundidade: 70 Estado:
#  [[8 1 3]
#  [4 6 2]
#  [7 5 0]]
# Profundidade: 71 Estado:
#  [[8 1 3]
#  [4 6 2]
#  [7 0 5]]
# Profundidade: 72 Estado:
#  [[8 1 3]
#  [4 6 2]
#  [0 7 5]]
# Profundidade: 73 Estado:
#  [[8 1 3]
#  [0 6 2]
#  [4 7 5]]
# Profundidade: 74 Estado:
#  [[8 1 3]
#  [6 0 2]
#  [4 7 5]]
# Profundidade: 75 Estado:
#  [[8 1 3]
#  [6 2 0]
#  [4 7 5]]
# Profundidade: 76 Estado:
#  [[8 1 3]
#  [6 2 5]
#  [4 7 0]]
# Profundidade: 77 Estado:
#  [[8 1 3]
#  [6 2 5]
#  [4 0 7]]
# Profundidade: 78 Estado:
#  [[8 1 3]
#  [6 0 5]
#  [4 2 7]]
# Profundidade: 79 Estado:
#  [[8 1 3]
#  [6 5 0]
#  [4 2 7]]
# Profundidade: 80 Estado:
#  [[8 1 3]
#  [6 5 7]
#  [4 2 0]]
# Profundidade: 81 Estado:
#  [[8 1 3]
#  [6 5 7]
#  [4 0 2]]
# Profundidade: 82 Estado:
#  [[8 1 3]
#  [6 5 7]
#  [0 4 2]]
# Profundidade: 83 Estado:
#  [[8 1 3]
#  [0 5 7]
#  [6 4 2]]
# Profundidade: 84 Estado:
#  [[8 1 3]
#  [5 0 7]
#  [6 4 2]]
# Profundidade: 85 Estado:
#  [[8 1 3]
#  [5 7 0]
#  [6 4 2]]
# Profundidade: 86 Estado:
#  [[8 1 3]
#  [5 7 2]
#  [6 4 0]]
# Profundidade: 87 Estado:
#  [[8 1 3]
#  [5 7 2]
#  [6 0 4]]
# Profundidade: 88 Estado:
#  [[8 1 3]
#  [5 7 2]
#  [0 6 4]]
# Profundidade: 89 Estado:
#  [[8 1 3]
#  [0 7 2]
#  [5 6 4]]
# Profundidade: 90 Estado:
#  [[8 1 3]
#  [7 0 2]
#  [5 6 4]]
# Profundidade: 91 Estado:
#  [[8 1 3]
#  [7 2 0]
#  [5 6 4]]
# Profundidade: 92 Estado:
#  [[8 1 3]
#  [7 2 4]
#  [5 6 0]]
# Profundidade: 93 Estado:
#  [[8 1 0]
#  [7 2 3]
#  [5 6 4]]
# Profundidade: 94 Estado:
#  [[8 0 1]
#  [7 2 3]
#  [5 6 4]]
# Profundidade: 95 Estado:
#  [[0 8 1]
#  [7 2 3]
#  [5 6 4]]
# Profundidade: 96 Estado:
#  [[7 8 1]
#  [0 2 3]
#  [5 6 4]]
# Profundidade: 97 Estado:
#  [[7 8 1]
#  [2 0 3]
#  [5 6 4]]
# Profundidade: 98 Estado:
#  [[7 8 1]
#  [2 3 0]
#  [5 6 4]]
# Profundidade: 99 Estado:
#  [[7 8 1]
#  [2 3 4]
#  [5 6 0]]
# Profundidade: 100 Estado:
#  [[7 8 1]
#  [2 3 4]
#  [5 0 6]]
# Profundidade: 101 Estado:
#  [[7 8 0]
#  [2 3 1]
#  [5 6 4]]
# Profundidade: 102 Estado:
#  [[7 8 1]
#  [2 6 3]
#  [5 0 4]]
# Profundidade: 103 Estado:
#  [[7 0 1]
#  [2 8 3]
#  [5 6 4]]
# Profundidade: 104 Estado:
#  [[7 8 1]
#  [5 2 3]
#  [0 6 4]]
# Profundidade: 105 Estado:
#  [[8 2 1]
#  [7 0 3]
#  [5 6 4]]
# Profundidade: 106 Estado:
#  [[8 1 3]
#  [7 6 2]
#  [5 0 4]]
# Profundidade: 107 Estado:
#  [[8 0 3]
#  [7 1 2]
#  [5 6 4]]
# Profundidade: 108 Estado:
#  [[0 1 3]
#  [8 7 2]
#  [5 6 4]]
# Profundidade: 109 Estado:
#  [[8 1 3]
#  [5 0 2]
#  [6 7 4]]
# Profundidade: 110 Estado:
#  [[8 1 0]
#  [5 7 3]
#  [6 4 2]]
# Profundidade: 111 Estado:
#  [[8 1 3]
#  [5 4 7]
#  [6 0 2]]
# Profundidade: 112 Estado:
#  [[8 0 3]
#  [5 1 7]
#  [6 4 2]]
# Profundidade: 113 Estado:
#  [[0 1 3]
#  [8 5 7]
#  [6 4 2]]
# Profundidade: 114 Estado:
#  [[8 1 3]
#  [6 0 7]
#  [4 5 2]]
# Profundidade: 115 Estado:
#  [[8 1 0]
#  [6 5 3]
#  [4 2 7]]
# Profundidade: 116 Estado:
#  [[8 1 3]
#  [0 6 5]
#  [4 2 7]]
# Profundidade: 117 Estado:
#  [[8 0 3]
#  [6 1 5]
#  [4 2 7]]
# Profundidade: 118 Estado:
#  [[8 1 0]
#  [6 2 3]
#  [4 7 5]]
# Profundidade: 119 Estado:
#  [[8 1 3]
#  [6 7 2]
#  [4 0 5]]
# Profundidade: 120 Estado:
#  [[8 0 3]
#  [6 1 2]
#  [4 7 5]]
# Profundidade: 121 Estado:
#  [[0 1 3]
#  [8 6 2]
#  [4 7 5]]
# Profundidade: 122 Estado:
#  [[8 1 3]
#  [4 0 2]
#  [7 6 5]]
# Profundidade: 123 Estado:
#  [[8 1 0]
#  [4 6 3]
#  [7 5 2]]
# Profundidade: 124 Estado:
#  [[8 1 3]
#  [4 5 6]
#  [7 0 2]]
# Profundidade: 125 Estado:
#  [[8 0 3]
#  [4 1 6]
#  [7 5 2]]
# Profundidade: 126 Estado:
#  [[0 1 3]
#  [8 4 6]
#  [7 5 2]]
# Profundidade: 127 Estado:
#  [[8 1 3]
#  [7 0 6]
#  [5 4 2]]
# Profundidade: 128 Estado:
#  [[8 1 0]
#  [7 4 3]
#  [5 2 6]]
# Profundidade: 129 Estado:
#  [[8 1 3]
#  [7 2 4]
#  [5 0 6]]
# Profundidade: 130 Estado:
#  [[8 0 3]
#  [7 1 4]
#  [5 2 6]]
# Profundidade: 131 Estado:
#  [[0 1 3]
#  [8 7 4]
#  [5 2 6]]
# Profundidade: 132 Estado:
#  [[8 1 3]
#  [5 0 4]
#  [2 7 6]]
# Profundidade: 133 Estado:
#  [[8 1 0]
#  [5 7 3]
#  [2 6 4]]
# Profundidade: 134 Estado:
#  [[8 1 3]
#  [5 6 7]
#  [2 0 4]]
# Profundidade: 135 Estado:
#  [[8 0 3]
#  [5 1 7]
#  [2 6 4]]
# Profundidade: 136 Estado:
#  [[0 1 3]
#  [8 5 7]
#  [2 6 4]]
# Profundidade: 137 Estado:
#  [[8 1 3]
#  [2 0 7]
#  [6 5 4]]
# Profundidade: 138 Estado:
#  [[8 1 0]
#  [2 5 3]
#  [6 4 7]]
# Profundidade: 139 Estado:
#  [[8 1 3]
#  [2 4 5]
#  [6 0 7]]
# Profundidade: 140 Estado:
#  [[8 0 3]
#  [2 1 5]
#  [6 4 7]]
# Profundidade: 141 Estado:
#  [[8 1 3]
#  [6 2 5]
#  [0 4 7]]
# Profundidade: 142 Estado:
#  [[1 2 3]
#  [8 0 5]
#  [6 4 7]]
# Profundidade: 143 Estado:
#  [[1 3 5]
#  [8 4 2]
#  [6 0 7]]
# Profundidade: 144 Estado:
#  [[1 0 5]
#  [8 3 2]
#  [6 4 7]]
# Profundidade: 145 Estado:
#  [[0 3 5]
#  [1 8 2]
#  [6 4 7]]
# Profundidade: 146 Estado:
#  [[1 3 5]
#  [6 0 2]
#  [4 8 7]]
# Profundidade: 147 Estado:
#  [[1 3 0]
#  [6 8 5]
#  [4 7 2]]
# Profundidade: 148 Estado:
#  [[1 3 5]
#  [6 7 8]
#  [4 0 2]]
# Profundidade: 149 Estado:
#  [[1 0 5]
#  [6 3 8]
#  [4 7 2]]
# Profundidade: 150 Estado:
#  [[0 3 5]
#  [1 6 8]
#  [4 7 2]]
# Profundidade: 151 Estado:
#  [[1 3 5]
#  [4 0 8]
#  [7 6 2]]
# Profundidade: 152 Estado:
#  [[1 3 0]
#  [4 6 5]
#  [7 2 8]]
# Profundidade: 153 Estado:
#  [[1 3 5]
#  [0 4 6]
#  [7 2 8]]
# Profundidade: 154 Estado:
#  [[1 0 5]
#  [4 3 6]
#  [7 2 8]]
# Profundidade: 155 Estado:
#  [[0 3 5]
#  [1 2 6]
#  [4 7 8]]
# Profundidade: 156 Estado:
#  [[1 3 5]
#  [2 7 6]
#  [4 0 8]]
# Profundidade: 157 Estado:
#  [[1 0 5]
#  [2 3 6]
#  [4 7 8]]
# Profundidade: 158 Estado:
#  [[1 3 0]
#  [2 6 5]
#  [4 7 8]]
# Profundidade: 159 Estado:
#  [[1 3 5]
#  [2 0 8]
#  [4 6 7]]
# Profundidade: 160 Estado:
#  [[0 3 5]
#  [1 6 8]
#  [2 4 7]]
# Profundidade: 161 Estado:
#  [[1 3 5]
#  [6 4 8]
#  [2 0 7]]
# Profundidade: 162 Estado:
#  [[1 0 5]
#  [6 3 8]
#  [2 4 7]]
# Profundidade: 163 Estado:
#  [[1 3 0]
#  [6 8 5]
#  [2 4 7]]
# Profundidade: 164 Estado:
#  [[1 3 5]
#  [6 0 7]
#  [2 8 4]]
# Profundidade: 165 Estado:
#  [[0 3 5]
#  [1 8 7]
#  [6 2 4]]
# Profundidade: 166 Estado:
#  [[1 3 5]
#  [8 2 7]
#  [6 0 4]]
# Profundidade: 167 Estado:
#  [[1 0 5]
#  [8 3 7]
#  [6 2 4]]
# Profundidade: 168 Estado:
#  [[1 3 0]
#  [8 7 5]
#  [6 2 4]]
# Profundidade: 169 Estado:
#  [[1 3 5]
#  [8 0 4]
#  [6 7 2]]
# Profundidade: 170 Estado:
#  [[0 3 5]
#  [1 7 4]
#  [8 6 2]]
# Profundidade: 171 Estado:
#  [[1 3 5]
#  [7 6 4]
#  [8 0 2]]
# Profundidade: 172 Estado:
#  [[1 0 5]
#  [7 3 4]
#  [8 6 2]]
# Profundidade: 173 Estado:
#  [[1 3 0]
#  [7 4 5]
#  [8 6 2]]
# Profundidade: 174 Estado:
#  [[1 3 5]
#  [7 0 2]
#  [8 4 6]]
# Profundidade: 175 Estado:
#  [[0 3 5]
#  [1 4 2]
#  [7 8 6]]
# Profundidade: 176 Estado:
#  [[1 3 5]
#  [4 8 2]
#  [7 0 6]]
# Profundidade: 177 Estado:
#  [[1 0 5]
#  [4 3 2]
#  [7 8 6]]
# Profundidade: 178 Estado:
#  [[1 3 5]
#  [4 2 6]
#  [7 8 0]]
# Profundidade: 179 Estado:
#  [[0 1 3]
#  [4 2 5]
#  [7 8 6]]
# Profundidade: 180 Estado:
#  [[1 2 3]
#  [4 0 5]
#  [7 8 6]]
# Não foi possível encontrar uma solução.
